# %%
iter = 100

for j in range(iter):     
     AB = BC = CD = DE = EF = FA = AC = BD = CE = DF = EA = FB = AD = BE = CF = 0
     import random
     uncon_nodes = [1,2,3,4,5,6]
     for i in range (3):
          n = random.choice(uncon_nodes)
          uncon_nodes.remove(n)
          m = random.choice(uncon_nodes)
          uncon_nodes.remove(m)
          if (n == 1 and m == 2) or (n == 2 and m == 1): AB = 1
          if (n == 2 and m == 3) or (n == 3 and m == 2): BC = 1
          if (n == 3 and m == 4) or (n == 4 and m == 3): CD = 1
          if (n == 4 and m == 5) or (n == 5 and m == 4): DE = 1
          if (n == 5 and m == 6) or (n == 6 and m == 5): EF = 1
          if (n == 6 and m == 1) or (n == 1 and m == 6): FA = 1
          if (n == 1 and m == 3) or (n == 3 and m == 1): AC = 1
          if (n == 2 and m == 4) or (n == 4 and m == 2): BD = 1
          if (n == 3 and m == 5) or (n == 5 and m == 3): CE = 1
          if (n == 4 and m == 6) or (n == 6 and m == 4): DF = 1
          if (n == 5 and m == 1) or (n == 1 and m == 5): EA = 1
          if (n == 6 and m == 2) or (n == 2 and m == 6): FB = 1
          if (n == 1 and m == 4) or (n == 4 and m == 1): AD = 1
          if (n == 2 and m == 5) or (n == 5 and m == 2): BE = 1
          if (n == 3 and m == 6) or (n == 6 and m == 3): CF = 1

     o = random.randint(1,3)
     if o == 1: AB = 1
     o = random.randint(1,3)
     if o == 1: BC = 1
     o = random.randint(1,3)
     if o == 1: CD = 1
     o = random.randint(1,3)
     if o == 1: DE = 1
     o = random.randint(1,3)
     if o == 1: EF = 1
     o = random.randint(1,3)
     if o == 1: FA = 1
     o = random.randint(1,3)
     if o == 1: AC = 1
     o = random.randint(1,3)
     if o == 1: BD = 1
     o = random.randint(1,3)
     if o == 1: CE = 1
     o = random.randint(1,3)
     if o == 1: DF = 1
     o = random.randint(1,3)
     if o == 1: EA = 1
     o = random.randint(1,3)
     if o == 1: FB = 1
     o = random.randint(1,3)
     if o == 1: AD = 1
     o = random.randint(1,3)
     if o == 1: BE = 1
     o = random.randint(1,3)
     if o == 1: CF = 1

     import pandas as pd
     df = []
     df.append(['Source','Target','Type'])
     if AB == 1: df.append(['A','B',2]); df.append(['B','A',2])
     if BC == 1: df.append(['B','C',2]); df.append(['C','B',2])
     if CD == 1: df.append(['C','D',2]); df.append(['D','C',2])
     if DE == 1: df.append(['D','E',2]); df.append(['E','D',2])
     if EF == 1: df.append(['E','F',2]); df.append(['F','E',2])
     if FA == 1: df.append(['F','A',2]); df.append(['A','F',2])
     if AC == 1: df.append(['A','C',2]); df.append(['C','A',2])
     if BD == 1: df.append(['B','D',2]); df.append(['D','B',2])
     if CE == 1: df.append(['C','E',2]); df.append(['E','C',2])
     if DF == 1: df.append(['D','F',2]); df.append(['F','D',2])
     if EA == 1: df.append(['E','A',2]); df.append(['A','E',2])
     if FB == 1: df.append(['F','B',2]); df.append(['B','F',2])
     if AD == 1: df.append(['A','D',2]); df.append(['D','A',2])
     if BE == 1: df.append(['B','E',2]); df.append(['E','B',2])
     if CF == 1: df.append(['C','F',2]); df.append(['F','C',2])

     import numpy as np
     topo_name = 'TS{}.topo'
     np.savetxt(topo_name.format(j), df, delimiter = '\t', fmt = '% s')
